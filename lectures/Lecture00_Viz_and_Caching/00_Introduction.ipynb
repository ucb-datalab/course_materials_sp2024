# %%
# %run ../talktools.py
# Out:
# <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" crossorigin="anonymous"></script>
#
# <style>
#
# @import url(https://fonts.googleapis.com/css?family=Open+Sans);body{
#    font-family: 'Open Sans';
#    font-size: 125%;
# }
#
# .talk_title
# {
#   color: #498AF3;
#   font-size: 275%;
#   font-weight:bold;
#   line-height: 1.3;
#   margin: 10px 50px 10px;
#   }
#
# .subtitle
# {
#   color: #386BBC;
#   font-size: 180%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 20px 50px 20px;
#   }
#
# .rendered_html h1
# {
#   color: #498AF3;
#   line-height: 1.2;
#   margin: 0.15em 0em 0.5em;
#   page-break-before: always;
#   text-align: center;
#   }
#
#
# .center
# {
#   text-align: center;
#   }
#
# .nb_link
# {
#     padding-bottom: 0.5em;
# }
#
# </style>

# %% [markdown]
# # Meeting/Lecture 0
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ucb-datalab/course_materials_2022/blob/main/Lectures/Lecture0_Viz_and_Gaia/00_Introduction.ipynb) [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/ucb-datalab/course_materials_2022/main?filepath=Lectures%2FLecture0_Viz_and_Gaia%2F00_Introduction.ipynb)
#
# Or follow along locally:
#
# ```bash
# git clone https://github.com/ucb-datalab/course_materials_2022.git
# cd course_materials_2022
# jupyter notebook
# ```
#
# ## Agenda for today
#
# * Introduction (this notebook, *00_Introduction*)
#
# * Class Logistics
#
# * Visualization (*01_plotting_and_viz_intro*)
#
# * Lab \#0: Getting Started (in groups)
#
#    * Report out by group
#
# * Caching (*02_caching.ipynb*)
#
# * Gaia presentation (if time)
#
# * Office Hours

# %% [markdown]
# ## Class Logistics
#
# ### Course Aims
#
# - Introduce and motivate a range of analysis techniques and data pipelining
# - Gain practical, in-depth experience doing inference on real, open-ended modern astronomical challenges
# - Build reproducible, well-tested, well-documented software & infrastructure
# - Learn to work with open data and code, and in an open science environment
# - Hone presentation (speaking & visualization) skills
# - Develop skills for future in academia, industry, …
#
# ### Communication
#
# * Main communication channel for us is Ed Discussion (https://edstem.org/us/courses/25141/discussion/). Please sign up now if you haven't already.
#
# * Course website will contain relevant links (https://ucb-datalab.github.io/), mostly pointing to the online material in GitHub (https://github.com/ucb-datalab/course_materials_2022)
#
# * Labs and checkpoints to be submitted using bCourses.
#
#
# ### Course Format
#
# - 4 credits (grad and undergrad)
# - Twice weekly 1.5 hour meeting
# - “Show & tell” progress reports + instructor lecture
# - 4 labs (numbered 0-3)
# - Will require a fair amount of dedicated coding time
# - It WILL fulfill the astro major lab requirement
# - Those registered for graduate version of class will do a more in-depth labs
#
#
# ### Lectures
#
# * Monday and Wednesday 2:30-4 pm in Campbell 131 (or see online notes)
#
# * We encourage you to participate during lecture by asking questions
#
# ### Office Hours
#
# * Jessica: Wednesday 4-5 pm, Campbell 501
# * Aaron: Wednesday 4-5 pm, Campbell 501
# * Natasha: Monday 5-6 pm, Campbell 131
# * Jingshu: Monday 6-7 pm, Campbell 131
# * By appointment
#
#
# ### Grading
# * 10%: Class Participation -- Active engagement in class discussion and lecture, participation during "show and tell", Ed Discussion Q&A, office hours; we know you may need to miss lecture (e.g. illness), and therefore there are several ways to get a good participation grade
# * 65%: Lab Reports/Notebooks -- due before specified class, -10% for each day late, you can collaborate with people in the class, but all work, writeups, notebooks, coding, plots, etc. MUST be your own
# * 25%: Lab Checkpoints -- each week, graded on completeness, not accuracy (mostly), __2 lowest checkpoint scores will be dropped__
#
# ### Datahub
# * You can execute your labs locally or using Berkeley's datahub: https://astro.datahub.berkeley.edu.  You will need to use python.
#
# ### Waitlist
# * It looks like we will be able to enroll the entire waitlist, pending some paperwork for a grader.
#
# ### Astro background
# * This is an astronomy class.  We will do our best to give you the base level astronomy knowledge needed for each lab. For those without astro backgrounds, it will take extra time to understand the astronomy.  Ask on Ed Discussion, office hours, etc.  We are happy to help.
#
# ### Coding background
# * This is a coding intensive class. We will use python.  If you're not already comfortable working in python, this may not be the class for you.  We are here to help with coding questions as best we can.
#
# ### Time Mangement
# * This is a time intesnive lab class. It usually doesn't work well to start working on checkpoints, labs, etc. right before they are due.  If you're taking a heavy course load this semester, you may find yourself really crunched for time because this class is time intensive.
#
# ### Answering questions on Ed Discussion
# * Please don't email us quesitons about your code/checkpoint.  Use Ed Discussion.
# * We do our best to answer questions, but we also not always online.  We may not get to questions before a deadline or as quickly as you would like.  That's part of time management.  We encourage students to answer each other's questions, that's really the best use of Piazza and helps your participation grade.
