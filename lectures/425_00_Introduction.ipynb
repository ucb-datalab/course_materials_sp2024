# %%
# %run talktools.py
# Out:
# <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" crossorigin="anonymous"></script>
#
# <style>
#
# @import url(https://fonts.googleapis.com/css?family=Open+Sans);body{
#    font-family: 'Open Sans';
#    font-size: 125%;
# }
#
# .talk_title
# {
#   color: #498AF3;
#   font-size: 275%;
#   font-weight:bold;
#   line-height: 1.3;
#   margin: 10px 50px 10px;
#   }
#
# .subtitle
# {
#   color: #386BBC;
#   font-size: 180%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 20px 50px 20px;
#   }
#
# .rendered_html h1
# {
#   color: #498AF3;
#   line-height: 1.2;
#   margin: 0.15em 0em 0.5em;
#   page-break-before: always;
#   text-align: center;
#   }
#
#
# .center
# {
#   text-align: center;
#   }
#
# .nb_link
# {
#     padding-bottom: 0.5em;
# }
#
# </style>

# %% [markdown]
# # April 25
#
# ## Agenda
#
# * Introduction (this notebook, *00_Introduction*)
# * Work/question time
#
# ## Office Hours this week
#
# * Anna: Friday 10:30-11:30am in 219 Campbell
#
# ## Office Hours during Reading Week
#
# * Anna: Monday 2:30-3:30pm in 355 Campbell
# * Dan: Tuesday 2-3pm in 131 Campbell
# * TALC: Wednesday 2-4pm in 131 Campbell
# * Oliva: Friday 10:30-11:30am in 219 Campbell
#
# ## Due dates
# * Lab 3 checkpoint 3 due by 11:59pm on Tuesday 4/30
# * Lab 3 full report due by 11:59pm on Friday 5/3
# * Any late work (for partial credit) needs to be submitted by 11:59pm on Friday 5/3
# * Late labs due by 11:59pm on Friday 5/3
#
# ## Course Evals
# * Currently 11/23 submitted (47%)
# * Target >= 18 people (80%)
#  - 1 percentage point of extra credit
# * Due by 11:59pm on Sunday 5/5
#
# ## Skills covered this semester
#
# * Sophisticated ADQL queries
# * Caching
# * time series analysis
# * Fourier Transforms / Lomb-Scargle periodograms
# * Coding up and solving maxtrix / linear algebra equations in python
# * cross validation
# * Fourier Decomposition
# * $\chi^2$ fitting
# * liklihood functions, priors, Bayesian inference
# * multi-component time series (e.g., RRc, Blahzko effects)
# * outlier rejection
# * Metropolis-Hastings & MCMC
# * PyMC
# * Posterior visualization (arviz, corner)
# * creating and comparing spatial maps
# * Linear models
# * Data Driven models
# * Non-linear optimization
# * regularization / re-scaling
# * error weighting
# * model gradients
# * model residual analysis
# * Image classification
# * Covariance & Correlation Matrices
# * Decision Trees
# * Neural Nets
# * Generator Functions
# * Memory Management
# * Overfitting
# * Data Augmentation
#
#
#
# ## Getting these notebooks
# ```bash
# git clone https://github.com/ucb-datalab/course_materials_2024.git
# cd course_materials_2024
# jupyter notebook
# ```
